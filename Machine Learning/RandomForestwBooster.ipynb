# %%
# Initial imports.
import pandas as pd
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Loading data
file_path = Path("../final_pro/All_Fighters_aligned.csv")
df_fighters = pd.read_csv(file_path)
df_fighters.head()
# Out:
#    Results  R_avg_KD  R_avg_opp_KD  R_avg_SIG_STR_pct  R_avg_opp_SIG_STR_pct  \
# 0        1  1.000000      0.000000           0.500000               0.460000
# 1        1  1.031250      0.062500           0.576875               0.381250
# 2        1  0.546875      0.187500           0.538906               0.598594
# 3        0       NaN           NaN                NaN                    NaN
# 4        0  0.000000      0.000977           0.403076               0.554961
#
#    R_avg_TD_pct  R_avg_opp_TD_pct  R_avg_SUB_ATT  R_avg_opp_SUB_ATT  \
# 0      0.000000           0.00000       0.000000            0.00000
# 1      0.406250           0.11625       0.250000            1.18750
# 2      0.000000           0.31250       0.000000            0.25000
# 3           NaN               NaN            NaN                NaN
# 4      0.511719           0.62875       0.231445            0.03125
#
#    R_avg_REV  ...  R_win_by_Decision_Split  R_win_by_Decision_Unanimous  \
# 0    0.00000  ...                        0                            0
# 1    0.37500  ...                        1                            0
# 2    0.00000  ...                        0                            1
# 3        NaN  ...                        0                            0
# 4    0.03125  ...                        0                            1
#
#    R_win_by_KO/TKO  R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  \
# 0                1                    0                             0
# 1                3                    0                             0
# 2                3                    0                             0
# 3                0                    0                             0
# 4                2                    2                             0
#
#    R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0        170.18       177.80         135.0   31.0   27.0
# 1        182.88       187.96         185.0   32.0   28.0
# 2        187.96       190.50         264.0   32.0   28.0
# 3        160.02       160.02         115.0   28.0   25.0
# 4        167.64       172.72         135.0   29.0   43.0
#
# [5 rows x 69 columns]

# %%
df_fighters = df_fighters.dropna()
df_fighters
# Out:
#       Results  R_avg_KD  R_avg_opp_KD  R_avg_SIG_STR_pct  \
# 0           1  1.000000      0.000000           0.500000
# 1           1  1.031250      0.062500           0.576875
# 2           1  0.546875      0.187500           0.538906
# 4           0  0.000000      0.000977           0.403076
# 5           0  0.312500      0.015625           0.565156
# ...       ...       ...           ...                ...
# 5929        1  0.000000      0.000000           0.680000
# 5947        1  0.000000      0.000000           0.523750
# 5957        0  0.000000      0.000000           0.547500
# 5967        1  0.000000      0.000000           0.695000
# 5979        0  0.000000      0.000000           0.940000
#
#       R_avg_opp_SIG_STR_pct  R_avg_TD_pct  R_avg_opp_TD_pct  R_avg_SUB_ATT  \
# 0                  0.460000      0.000000          0.000000       0.000000
# 1                  0.381250      0.406250          0.116250       0.250000
# 2                  0.598594      0.000000          0.312500       0.000000
# 4                  0.554961      0.511719          0.628750       0.231445
# 5                  0.343594      0.337031          0.048906       0.039062
# ...                     ...           ...               ...            ...
# 5929               0.420000      1.000000          0.000000       0.000000
# 5947               0.465000      0.718750          0.000000       1.062500
# 5957               0.750000      0.437500          0.000000       1.125000
# 5967               0.500000      0.875000          0.000000       0.250000
# 5979               0.750000      0.750000          0.000000       0.500000
#
#       R_avg_opp_SUB_ATT  R_avg_REV  ...  R_win_by_Decision_Split  \
# 0               0.00000    0.00000  ...                        0
# 1               1.18750    0.37500  ...                        1
# 2               0.25000    0.00000  ...                        0
# 4               0.03125    0.03125  ...                        0
# 5               0.00000    0.00000  ...                        1
# ...                 ...        ...  ...                      ...
# 5929            0.00000    0.00000  ...                        0
# 5947            0.00000    0.00000  ...                        0
# 5957            0.00000    0.00000  ...                        0
# 5967            0.00000    0.00000  ...                        0
# 5979            0.00000    0.00000  ...                        0
#
#       R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# 0                               0                1                    0
# 1                               0                3                    0
# 2                               1                3                    0
# 4                               1                2                    2
# 5                               2                2                    2
# ...                           ...              ...                  ...
# 5929                            0                0                    1
# 5947                            0                1                    2
# 5957                            0                1                    2
# 5967                            0                1                    1
# 5979                            0                1                    1
#
#       R_win_by_TKO_Doctor_Stoppage  R_Height_cms  R_Reach_cms  R_Weight_lbs  \
# 0                                0        170.18       177.80         135.0
# 1                                0        182.88       187.96         185.0
# 2                                0        187.96       190.50         264.0
# 4                                0        167.64       172.72         135.0
# 5                                0        182.88       190.50         155.0
# ...                            ...           ...          ...           ...
# 5929                             0        185.42       190.50         205.0
# 5947                             0        185.42       182.88         205.0
# 5957                             0        185.42       182.88         205.0
# 5967                             0        185.42       182.88         205.0
# 5979                             0        185.42       182.88         205.0
#
#       B_age  R_age
# 0      31.0   27.0
# 1      32.0   28.0
# 2      32.0   28.0
# 4      29.0   43.0
# 5      27.0   41.0
# ...     ...    ...
# 5929   30.0   31.0
# 5947   28.0   32.0
# 5957   28.0   31.0
# 5967   37.0   31.0
# 5979   28.0   31.0
#
# [5010 rows x 69 columns]

# %%
# Define the features set.
X = df_fighters.copy()
X = X.drop("Results", axis=1)
X.head()
# Out:
#    R_avg_KD  R_avg_opp_KD  R_avg_SIG_STR_pct  R_avg_opp_SIG_STR_pct  \
# 0  1.000000      0.000000           0.500000               0.460000
# 1  1.031250      0.062500           0.576875               0.381250
# 2  0.546875      0.187500           0.538906               0.598594
# 4  0.000000      0.000977           0.403076               0.554961
# 5  0.312500      0.015625           0.565156               0.343594
#
#    R_avg_TD_pct  R_avg_opp_TD_pct  R_avg_SUB_ATT  R_avg_opp_SUB_ATT  \
# 0      0.000000          0.000000       0.000000            0.00000
# 1      0.406250          0.116250       0.250000            1.18750
# 2      0.000000          0.312500       0.000000            0.25000
# 4      0.511719          0.628750       0.231445            0.03125
# 5      0.337031          0.048906       0.039062            0.00000
#
#    R_avg_REV  R_avg_opp_REV  ...  R_win_by_Decision_Split  \
# 0    0.00000           0.00  ...                        0
# 1    0.37500           0.25  ...                        1
# 2    0.00000           0.00  ...                        0
# 4    0.03125           0.50  ...                        0
# 5    0.00000           0.50  ...                        1
#
#    R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# 0                            0                1                    0
# 1                            0                3                    0
# 2                            1                3                    0
# 4                            1                2                    2
# 5                            2                2                    2
#
#    R_win_by_TKO_Doctor_Stoppage  R_Height_cms  R_Reach_cms  R_Weight_lbs  \
# 0                             0        170.18       177.80         135.0
# 1                             0        182.88       187.96         185.0
# 2                             0        187.96       190.50         264.0
# 4                             0        167.64       172.72         135.0
# 5                             0        182.88       190.50         155.0
#
#    B_age  R_age
# 0   31.0   27.0
# 1   32.0   28.0
# 2   32.0   28.0
# 4   29.0   43.0
# 5   27.0   41.0
#
# [5 rows x 68 columns]

# %%
# Define the target set.
y = df_fighters["Results"].values
y[:5]
# Out:
# array([1, 1, 1, 0, 0], dtype=int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Determine the shape of our training and testing sets.
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3757, 68)
# (1253, 68)
# (3757,)
# (1253,)

# %%
# Create a random forest classifier.
rf_model = RandomForestClassifier(n_estimators=128, random_state=1)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train, y_train)

# %%
# Making predictions using the testing data.
predictions = rf_model.predict(X_test)
predictions
# Out:
# array([1, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
# Calculating the confusion matrix.
conmat = confusion_matrix(y_test, predictions)

# Create a DataFrame from the confusion matrix.
conmat_df = pd.DataFrame(
    conmat, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

conmat_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0           78          368
# Actual 1           79          728

# %%
# Calculating the accuracy score.
acc_score = accuracy_score(y_test, predictions)
acc_score
# Out:
# 0.6432561851556265

# %%
# Displaying results
print("Confusion Matrix")
display(conmat_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0           78          368
# Actual 1           79          728
# Accuracy Score : 0.6432561851556265
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.17      0.26       446
#            1       0.66      0.90      0.77       807
#
#     accuracy                           0.64      1253
#    macro avg       0.58      0.54      0.51      1253
# weighted avg       0.60      0.64      0.58      1253

# %%
# Calculate feature importance in the Random Forest model.
importances = rf_model.feature_importances_
importances
# Out:
# array([0.01245542, 0.01132632, 0.01930065, 0.02464656, 0.01851798,
#        0.01541805, 0.01546489, 0.01381745, 0.00988488, 0.00891854,
#        0.01500027, 0.01514785, 0.01655214, 0.01935604, 0.01589096,
#        0.01831346, 0.01760065, 0.01907763, 0.01721682, 0.0157998 ,
#        0.01668056, 0.0148499 , 0.01675046, 0.01801853, 0.01667306,
#        0.02243546, 0.01817326, 0.01788537, 0.01925935, 0.01915711,
#        0.01655305, 0.01664363, 0.0167502 , 0.01632763, 0.01612485,
#        0.01713835, 0.01709863, 0.02101719, 0.01795126, 0.01762524,
#        0.01781015, 0.01812139, 0.01906012, 0.0181014 , 0.01656015,
#        0.0158481 , 0.01840188, 0.01932197, 0.01822009, 0.01593919,
#        0.00445173, 0.00696513, 0.00430127, 0.00776169, 0.00945492,
#        0.01396905, 0.        , 0.00077337, 0.0052882 , 0.00637045,
#        0.00648321, 0.00565346, 0.00130211, 0.01218349, 0.01239285,
#        0.01079963, 0.01810856, 0.023537  ])

# %%
# We can sort the features by their importance.
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.024646556017764543, 'R_avg_opp_SIG_STR_pct'),
#  (0.023536999756078206, 'R_age'),
#  (0.022435457260162082, 'R_avg_opp_HEAD_landed'),
#  (0.021017192165078045, 'R_avg_opp_DISTANCE_landed'),
#  (0.01935603514391338, 'R_avg_opp_SIG_STR_landed'),
#  (0.019321974937928046, 'R_avg_opp_CTRL_time(seconds)'),
#  (0.019300646667645492, 'R_avg_SIG_STR_pct'),
#  (0.01925934952842717, 'R_avg_opp_BODY_att'),
#  (0.019157109363268608, 'R_avg_opp_BODY_landed'),
#  (0.01907762611966717, 'R_avg_opp_TOTAL_STR_landed'),
#  (0.019060121214063162, 'R_avg_GROUND_att'),
#  (0.01851798264063817, 'R_avg_TD_pct'),
#  (0.01840188248340702, 'R_avg_CTRL_time(seconds)'),
#  (0.01831345532483518, 'R_avg_TOTAL_STR_landed'),
#  (0.01822008956437807, 'R_total_time_fought(seconds)'),
#  (0.01817325514556271, 'R_avg_BODY_att'),
#  (0.018121385202427884, 'R_avg_opp_CLINCH_landed'),
#  (0.018108559676100987, 'B_age'),
#  (0.018101401430795118, 'R_avg_GROUND_landed'),
#  (0.01801853195744801, 'R_avg_HEAD_landed'),
#  (0.017951258948529458, 'R_avg_CLINCH_att'),
#  (0.017885374519301417, 'R_avg_BODY_landed'),
#  (0.017810147039648613, 'R_avg_opp_CLINCH_att'),
#  (0.017625238487824886, 'R_avg_CLINCH_landed'),
#  (0.017600647493018894, 'R_avg_opp_TOTAL_STR_att'),
#  (0.01721682265567363, 'R_avg_TD_att'),
#  (0.017138354901027917, 'R_avg_DISTANCE_landed'),
#  (0.017098625303163487, 'R_avg_opp_DISTANCE_att'),
#  (0.016750458384302135, 'R_avg_HEAD_att'),
#  (0.01675020142606109, 'R_avg_opp_LEG_att'),
#  (0.01668055922227062, 'R_avg_opp_TD_att'),
#  (0.016673063173851914, 'R_avg_opp_HEAD_att'),
#  (0.016643627236148036, 'R_avg_LEG_landed'),
#  (0.016560147170984876, 'R_avg_opp_GROUND_att'),
#  (0.016553046364546405, 'R_avg_LEG_att'),
#  (0.016552141914154266, 'R_avg_opp_SIG_STR_att'),
#  (0.016327625256229588, 'R_avg_opp_LEG_landed'),
#  (0.0161248478002806, 'R_avg_DISTANCE_att'),
#  (0.015939188801115514, 'R_total_rounds_fought'),
#  (0.015890958584033978, 'R_avg_TOTAL_STR_att'),
#  (0.01584810356357277, 'R_avg_opp_GROUND_landed'),
#  (0.0157998045808724, 'R_avg_TD_landed'),
#  (0.015464892248426024, 'R_avg_SUB_ATT'),
#  (0.015418046283590477, 'R_avg_opp_TD_pct'),
#  (0.015147851570984397, 'R_avg_SIG_STR_landed'),
#  (0.015000270680559884, 'R_avg_SIG_STR_att'),
#  (0.01484990273071197, 'R_avg_opp_TD_landed'),
#  (0.013969052199437905, 'R_losses'),
#  (0.013817454244947706, 'R_avg_opp_SUB_ATT'),
#  (0.012455422857732597, 'R_avg_KD'),
#  (0.012392854758544635, 'R_Reach_cms'),
#  (0.012183489390446512, 'R_Height_cms'),
#  (0.011326323608074286, 'R_avg_opp_KD'),
#  (0.01079962923287192, 'R_Weight_lbs'),
#  (0.009884876866413515, 'R_avg_REV'),
#  (0.009454918534813743, 'R_wins'),
#  (0.0089185358589182, 'R_avg_opp_REV'),
#  (0.007761693675153335, 'R_longest_win_streak'),
#  (0.006965131661424065, 'R_current_win_streak'),
#  (0.006483212754800652, 'R_win_by_KO/TKO'),
#  (0.006370449789849747, 'R_win_by_Decision_Unanimous'),
#  (0.0056534613058764165, 'R_win_by_Submission'),
#  (0.005288203410062494, 'R_win_by_Decision_Split'),
#  (0.004451729625957095, 'R_total_title_bouts'),
#  (0.004301266539777428, 'R_current_lose_streak'),
#  (0.0013021072374615067, 'R_win_by_TKO_Doctor_Stoppage'),
#  (0.0007733685069619113, 'R_win_by_Decision_Majority'),
#  (0.0, 'R_draw')]

# %%
from sklearn.ensemble import GradientBoostingClassifier
learning_rates = [0.05, 0.1, 0.25, 0.5, 0.75, 1]
for learning_rate in learning_rates:
   classifier = GradientBoostingClassifier(n_estimators=20,
   learning_rate=learning_rate,
   max_features=5,
   max_depth=3,
   random_state=1)
   classifier.fit(X_train, y_train)
   print("Learning rate: ", learning_rate)
   print("Accuracy score (training): {0:.3f}".format(
       classifier.score(
           X_train,
           y_train)))
   print("Accuracy score (validation): {0:.3f}".format(
       classifier.score(
           X_test,
           y_test)))
# Out:
# Learning rate:  0.05
# Accuracy score (training): 0.645
# Accuracy score (validation): 0.644
# Learning rate:  0.1
# Accuracy score (training): 0.658
# Accuracy score (validation): 0.652
# Learning rate:  0.25
# Accuracy score (training): 0.693
# Accuracy score (validation): 0.652
# Learning rate:  0.5
# Accuracy score (training): 0.725
# Accuracy score (validation): 0.632
# Learning rate:  0.75
# Accuracy score (training): 0.724
# Accuracy score (validation): 0.629
# Learning rate:  1
# Accuracy score (training): 0.732
# Accuracy score (validation): 0.621

# %%
classifier = GradientBoostingClassifier(n_estimators=20,
   learning_rate=0.5, max_features=5, max_depth=3, random_state=0)

classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)

# %%
acc_score = accuracy_score(y_test, predictions)
print(f"Accuracy Score : {acc_score}")
# Out:
# Accuracy Score : 0.6456504389465283

# %%
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
   cm, index=["Actual 0", "Actual 1"],
   columns=["Predicted 0", "Predicted 1"]
)
display(cm_df)
# Out:
#           Predicted 0  Predicted 1
# Actual 0          106          340
# Actual 1          104          703

# %%
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.24      0.32       446
#            1       0.67      0.87      0.76       807
#
#     accuracy                           0.65      1253
#    macro avg       0.59      0.55      0.54      1253
# weighted avg       0.61      0.65      0.60      1253
